# %% [markdown]
# <a href="https://colab.research.google.com/github/mevangelista-alvarado/python_exercises/blob/main/1_solucion_problema_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![URC_LOGO.png](data:image/png;base64,...)

# %% [markdown]
# **Tema:** Cálculo de números factoriales
#
# **Autor:** Albert Alfonso Espinosa Sánchez
#
# **Github:** https://github.com/alberths-mx
#
# **CALCULEMOS UN NÚMERO FACTORIAL N!**
#
# Un número factorial es aquel producto de un número natural, el cual resultará de la multiplicación de los números consecutivos que lo anteceden. Ej. 4! (cuatro factorial) = 4x3x2x1
#
# En probabilidad, los números factoriales se emplean para obtener las distintas agrupaciones de datos que pueden dar lugar tanto a combinaciones como permutaciones.
#
# En la siguiente línea de código, donde se emplea lenguaje python podemos ingresar cualquier número factorial y obtener el resultado correspondiente.
#
# **Ejemplo:**

# %%
print ("CALCULEMOS UN NÚMERO FACTORIAL N!")
print ("")
numero = int(input("Introduzca un número entero cualquiera: "))
factorial = 1
i = 1
while (i <= numero):
    factorial = factorial * i
    i = i + 1
print ("El factorial de " + str(numero) + " es " + str(factorial))
# Out:
# CALCULEMOS UN NÚMERO FACTORIAL N!
#
# Introduzca un número entero cualquiera: 3
# El factorial de 3 es 6
